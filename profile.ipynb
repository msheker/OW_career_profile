# %%
from bs4 import BeautifulSoup as bs
import requests

# %%
soup = bs(requests.get("https://playoverwatch.com/en-us/career/pc/MehGL-1252/").text, 'html.parser')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
#  <head>
#   <link href="https://static.playoverwatch.com/img/favicon-696bc07714.ico" rel="icon" type="image/x-icon"/>
#   <title>
#    Career Overview - Overwatch
#   </title>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1, user-scalable=no" name="viewport"/>
#   <meta content="Overwatch Profiles" itemprop="name"/>
#   <meta content="Detailed statistics for Overwatch players on Overwatch accounts. View your profile or check out others." name="description"/>
#   <meta content="Detailed statistics for Overwatch players on Overwatch accounts. View your profile or check out others." itemprop="description"/>
#   <meta content="https://static.playoverwatch.com/img/logos/overwatch-share-4dab210e88.jpg" itemprop="image"/>
#   <link href="https://playoverwatch.com/en-us/career/pc/MehGL-1252/" rel="canonical"/>
#   <!--Opengraph Tags - http://ogp.me/-->
# ...

# %%
dir(soup)
# Out:
# ['ASCII_SPACES',
#  'DEFAULT_BUILDER_FEATURES',
#  'NO_PARSER_SPECIFIED_WARNING',
#  'ROOT_TAG_NAME',
#  '__bool__',
#  '__call__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__unicode__',
#  '__weakref__',
#  '_all_strings',
#  '_check_markup_is_url',
#  '_feed',
#  '_find_all',
#  '_find_one',
#  '_is_xml',
#  '_lastRecursiveChild',
#  '_last_descendant',
#  '_linkage_fixer',
#  '_most_recent_element',
#  '_namespaces',
#  '_popToTag',
#  '_should_pretty_print',
# ...

# %%
soup.findAll("div","competitive-rank-level")
# Out:
# [<div class="competitive-rank-level">2785</div>,
#  <div class="competitive-rank-level">2514</div>,
#  <div class="competitive-rank-level">2441</div>,
#  <div class="competitive-rank-level">2785</div>,
#  <div class="competitive-rank-level">2514</div>,
#  <div class="competitive-rank-level">2441</div>]

# %%
"""<select data-js="career-select" data-group-id="stats" class="dropdown-select-element" style="height: 30px;"><option value="0x02E00000FFFFFFFF" option-id="ALL HEROES">ALL HEROES</option><option value="0x02E000000000013B" option-id="Ana">Ana</option><option value="0x02E0000000000200" option-id="Ashe">Ashe</option><option value="0x02E0000000000221" option-id="Baptiste">Baptiste</option><option value="0x02E0000000000015" option-id="Bastion">Bastion</option><option value="0x02E0000000000195" option-id="Brigitte">Brigitte</option><option value="0x02E000000000007A" option-id="D.Va">D.Va</option><option value="0x02E0000000000206" option-id="Echo">Echo</option><option value="0x02E0000000000029" option-id="Genji">Genji</option><option value="0x02E0000000000005" option-id="Hanzo">Hanzo</option><option value="0x02E0000000000065" option-id="Junkrat">Junkrat</option><option value="0x02E0000000000079" option-id="Lúcio">Lúcio</option><option value="0x02E0000000000042" option-id="McCree">McCree</option><option value="0x02E00000000000DD" option-id="Mei">Mei</option><option value="0x02E0000000000004" option-id="Mercy">Mercy</option><option value="0x02E00000000001A2" option-id="Moira">Moira</option><option value="0x02E000000000013E" option-id="Orisa">Orisa</option><option value="0x02E0000000000008" option-id="Pharah">Pharah</option><option value="0x02E0000000000002" option-id="Reaper">Reaper</option><option value="0x02E0000000000007" option-id="Reinhardt">Reinhardt</option><option value="0x02E0000000000040" option-id="Roadhog">Roadhog</option><option value="0x02E000000000023B" option-id="Sigma">Sigma</option><option value="0x02E000000000006E" option-id="Soldier: 76">Soldier: 76</option><option value="0x02E000000000012E" option-id="Sombra">Sombra</option><option value="0x02E0000000000016" option-id="Symmetra">Symmetra</option><option value="0x02E0000000000006" option-id="Torbjörn">Torbjörn</option><option value="0x02E0000000000003" option-id="Tracer">Tracer</option><option value="0x02E000000000000A" option-id="Widowmaker">Widowmaker</option><option value="0x02E0000000000009" option-id="Winston">Winston</option><option value="0x02E00000000001CA" option-id="Wrecking Ball">Wrecking Ball</option><option value="0x02E0000000000068" option-id="Zarya">Zarya</option><option value="0x02E0000000000020" option-id="Zenyatta">Zenyatta</option></select>"""
# Out:
# '<select data-js="career-select" data-group-id="stats" class="dropdown-select-element" style="height: 30px;"><option value="0x02E00000FFFFFFFF" option-id="ALL HEROES">ALL HEROES</option><option value="0x02E000000000013B" option-id="Ana">Ana</option><option value="0x02E0000000000200" option-id="Ashe">Ashe</option><option value="0x02E0000000000221" option-id="Baptiste">Baptiste</option><option value="0x02E0000000000015" option-id="Bastion">Bastion</option><option value="0x02E0000000000195" option-id="Brigitte">Brigitte</option><option value="0x02E000000000007A" option-id="D.Va">D.Va</option><option value="0x02E0000000000206" option-id="Echo">Echo</option><option value="0x02E0000000000029" option-id="Genji">Genji</option><option value="0x02E0000000000005" option-id="Hanzo">Hanzo</option><option value="0x02E0000000000065" option-id="Junkrat">Junkrat</option><option value="0x02E0000000000079" option-id="Lúcio">Lúcio</option><option value="0x02E0000000000042" option-id="McCree">McCree</opt
# ...
